# %%
pip install basketball-reference-scraper
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# ...

# %%
# !pip install constants
# !pip install unidecode

# %%
from basketball_reference_scraper.players import get_stats,get_game_logs, get_player_headshot

# %%
from basketball_reference_scraper.players import get_stats

# %%
from basketball_reference_scraper.lookup import lookup

# %%
with open('listplayers') as f:
    targets = f.read().splitlines()

# %%
#experiments=targets[0:20]
#experiments

# %%
#dfs=[]
#for experiment in experiments:
    #try:
        #dfs.append(get_stats(experiment,ask_matches=False ).assign(Name=experiment))
    #except:
        #pass

# %%
dfs=[]
for target in targets:
    try:
        dfs.append(get_stats(target,ask_matches=False).assign(Name=target))
    except:
        pass

# %%
len(dfs)
# Out:
# 4781

# %%
alpha=pd.concat(dfs)
alpha
# Out:
#      SEASON   AGE TEAM LEAGUE  POS     G    GS    MP   FG   FGA  ...  ORB  \
# 0   2020-21  19.0  GSW    NBA    C    39    27  21.4  4.9   9.4  ...  1.4
# 0   2020-21  19.0  DET    NBA   PG    26    18  25.8  2.7   7.7  ...  0.2
# 0   2020-21  20.0  SAC    NBA   PG    58    20  30.1  5.0  10.7  ...  0.7
# 0   2020-21  19.0  CHO    NBA   PG    51    31  28.8  5.7  13.2  ...  1.2
# 0   2020-21  19.0  OKC    NBA   PF    45    28  24.2  3.1   9.1  ...  0.7
# ..      ...   ...  ...    ...  ...   ...   ...   ...  ...   ...  ...  ...
# 3   2018-19  21.0  LAL    NBA    C  33.0  12.0  15.6  3.4   5.8  ...  1.6
# 4   2018-19  21.0  LAC    NBA    C  26.0  25.0  20.2  3.8   7.2  ...  2.3
# 5   2019-20  22.0  LAC    NBA    C  72.0  70.0  18.4  3.3   5.3  ...  2.7
# 6   2020-21  23.0  LAC    NBA    C  72.0  33.0  22.3  3.6   5.5  ...  2.6
# 0   1948-49  29.0  WSC    BAA  NaN    56   NaN   NaN  1.8   5.8  ...  NaN
#
#     DRB  TRB  AST  STL  BLK  TOV   PF   PTS                Name
# ...

# %%
import pickle
alpha.to_pickle('data/nbaseasonstats')

# %%
alpha.to_csv('data/nbaseasonstatscsv')

# %%
df=get_stats('LaMarcus Aldridge')
# Out:
# You searched for "LaMarcus Aldridge"
# 1 result found.
# LaMarcus Aldridge
# Results for LaMarcus Aldridge:

# %%
df.assign(Name='LaMarcus Aldridge')
# Out:
#      SEASON   AGE TEAM LEAGUE POS  ...  BLK  TOV   PF   PTS               Name
# 0   2006-07  21.0  POR    NBA   C  ...  1.2  0.7  3.0   9.0  LaMarcus Aldridge
# 1   2007-08  22.0  POR    NBA  PF  ...  1.2  1.7  3.2  17.8  LaMarcus Aldridge
# 2   2008-09  23.0  POR    NBA  PF  ...  1.0  1.5  2.6  18.1  LaMarcus Aldridge
# 3   2009-10  24.0  POR    NBA  PF  ...  0.6  1.3  3.0  17.9  LaMarcus Aldridge
# 4   2010-11  25.0  POR    NBA  PF  ...  1.2  1.9  2.7  21.8  LaMarcus Aldridge
# 5   2011-12  26.0  POR    NBA  PF  ...  0.8  2.0  2.8  21.7  LaMarcus Aldridge
# 6   2012-13  27.0  POR    NBA  PF  ...  1.2  1.9  2.5  21.1  LaMarcus Aldridge
# 7   2013-14  28.0  POR    NBA  PF  ...  1.0  1.8  2.1  23.2  LaMarcus Aldridge
# 8   2014-15  29.0  POR    NBA  PF  ...  1.0  1.7  1.8  23.4  LaMarcus Aldridge
# 9   2015-16  30.0  SAS    NBA  PF  ...  1.1  1.3  2.0  18.0  LaMarcus Aldridge
# 10  2016-17  31.0  SAS    NBA  PF  ...  1.2  1.4  2.2  17.3  LaMarcus Aldridge
# ...
