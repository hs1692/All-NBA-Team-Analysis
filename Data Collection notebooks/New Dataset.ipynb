# %%
import pandas as pd

# %%
beta=pd.read_pickle('data/nbaseasonstats')
beta.rename(columns={'Name':'PLAYER'}, inplace=True)
beta.head()
# Out:
#     SEASON   AGE TEAM LEAGUE POS   G  GS    MP   FG   FGA  ...  ORB  DRB  TRB  \
# 0  2020-21  19.0  GSW    NBA   C  39  27  21.4  4.9   9.4  ...  1.4  4.4  5.8
# 0  2020-21  19.0  DET    NBA  PG  26  18  25.8  2.7   7.7  ...  0.2  2.4  2.7
# 0  2020-21  20.0  SAC    NBA  PG  58  20  30.1  5.0  10.7  ...  0.7  2.3  3.0
# 0  2020-21  19.0  CHO    NBA  PG  51  31  28.8  5.7  13.2  ...  1.2  4.7  5.9
# 0  2020-21  19.0  OKC    NBA  PF  45  28  24.2  3.1   9.1  ...  0.7  4.0  4.7
#
#    AST  STL  BLK  TOV   PF   PTS              PLAYER
# 0  0.7  0.3  0.9  1.5  3.1  11.5       James Wiseman
# 0  5.3  1.0  0.4  3.2  2.2   6.8       Killian Hayes
# 0  5.3  1.3  0.5  1.6  1.4  13.0   Tyrese Haliburton
# 0  6.1  1.6  0.4  2.8  2.7  15.7         LaMelo Ball
# 0  2.2  0.4  0.9  2.2  1.3   8.2  Aleksej Pokusevski
#
# [5 rows x 31 columns]

# %%
beta.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 31120 entries, 0 to 0
# Data columns (total 31 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   SEASON  31120 non-null  object
#  1   AGE     31097 non-null  float64
#  2   TEAM    31120 non-null  object
#  3   LEAGUE  31120 non-null  object
#  4   POS     29961 non-null  object
#  5   G       31091 non-null  object
#  6   GS      22523 non-null  object
#  7   MP      30006 non-null  object
#  8   FG      31075 non-null  object
#  9   FGA     31073 non-null  object
#  10  FG%     30947 non-null  object
#  11  3P      24641 non-null  object
#  12  3PA     24641 non-null  object
#  13  3P%     20655 non-null  object
#  14  2P      26294 non-null  object
#  15  2PA     26294 non-null  object
#  16  2P%     26118 non-null  object
#  17  eFG%    26178 non-null  object
#  18  FT      31075 non-null  object
#  19  FTA     31075 non-null  object
#  20  FT%     30008 non-null  object
#  21  ORB     26356 non-null  object
#  22  DRB     26333 non-null  object
#  23  TRB     30171 non-null  object
#  24  AST     31073 non-null  object
#  25  STL     25270 non-null  object
#  26  BLK     25281 non-null  object
#  27  TOV     25373 non-null  object
#  28  PF      31075 non-null  object
#  29  PTS     31075 non-null  object
#  30  PLAYER  31120 non-null  object
# dtypes: float64(1), object(30)
# memory usage: 7.6+ MB

# %%
beta['SEASON_COUNT']=beta.groupby('PLAYER')['SEASON'].cumcount()+1
beta.head()
# Out:
#     SEASON   AGE TEAM LEAGUE POS   G  GS    MP   FG   FGA  ...  DRB  TRB  AST  \
# 0  2020-21  19.0  GSW    NBA   C  39  27  21.4  4.9   9.4  ...  4.4  5.8  0.7
# 0  2020-21  19.0  DET    NBA  PG  26  18  25.8  2.7   7.7  ...  2.4  2.7  5.3
# 0  2020-21  20.0  SAC    NBA  PG  58  20  30.1  5.0  10.7  ...  2.3  3.0  5.3
# 0  2020-21  19.0  CHO    NBA  PG  51  31  28.8  5.7  13.2  ...  4.7  5.9  6.1
# 0  2020-21  19.0  OKC    NBA  PF  45  28  24.2  3.1   9.1  ...  4.0  4.7  2.2
#
#    STL  BLK  TOV   PF   PTS              PLAYER SEASON_COUNT
# 0  0.3  0.9  1.5  3.1  11.5       James Wiseman            1
# 0  1.0  0.4  3.2  2.2   6.8       Killian Hayes            1
# 0  1.3  0.5  1.6  1.4  13.0   Tyrese Haliburton            1
# 0  1.6  0.4  2.8  2.7  15.7         LaMelo Ball            1
# 0  0.4  0.9  2.2  1.3   8.2  Aleksej Pokusevski            1
#
# [5 rows x 32 columns]

# %%
threeseasons=beta[beta['SEASON_COUNT']<4]
threeseasons
# Out:
#      SEASON   AGE TEAM LEAGUE  POS     G    GS    MP   FG   FGA  ...  DRB  \
# 0   2020-21  19.0  GSW    NBA    C    39    27  21.4  4.9   9.4  ...  4.4
# 0   2020-21  19.0  DET    NBA   PG    26    18  25.8  2.7   7.7  ...  2.4
# 0   2020-21  20.0  SAC    NBA   PG    58    20  30.1  5.0  10.7  ...  2.3
# 0   2020-21  19.0  CHO    NBA   PG    51    31  28.8  5.7  13.2  ...  4.7
# 0   2020-21  19.0  OKC    NBA   PF    45    28  24.2  3.1   9.1  ...  4.0
# ..      ...   ...  ...    ...  ...   ...   ...   ...  ...   ...  ...  ...
# 0   1970-71  22.0  MIL    NBA   PG    53   NaN   7.5  0.9   2.5  ...  NaN
# 0   2016-17  19.0  LAL    NBA    C  38.0  11.0  16.0  3.3   6.3  ...  3.1
# 1   2017-18  20.0  LAL    NBA    C  43.0   0.0   9.5  1.4   2.8  ...  1.8
# 2   2018-19  21.0  TOT    NBA    C  59.0  37.0  17.6  3.6   6.4  ...  4.2
# 0   1948-49  29.0  WSC    BAA  NaN    56   NaN   NaN  1.8   5.8  ...  NaN
#
#     TRB  AST  STL  BLK  TOV   PF   PTS              PLAYER SEASON_COUNT
# 0   5.8  0.7  0.3  0.9  1.5  3.1  11.5       James Wiseman            1
# 0   2.7  5.3  1.0  0.4  3.2  2.2   6.8       Killian Hayes            1
# 0   3.0  5.3  1.3  0.5  1.6  1.4  13.0   Tyrese Haliburton            1
# 0   5.9  6.1  1.6  0.4  2.8  2.7  15.7         LaMelo Ball            1
# 0   4.7  2.2  0.4  0.9  2.2  1.3   8.2  Aleksej Pokusevski            1
# ..  ...  ...  ...  ...  ...  ...   ...                 ...          ...
# 0   0.9  1.4  NaN  NaN  NaN  0.6   2.2           Bill Zopf            1
# 0   4.2  0.8  0.4  0.9  0.8  1.7   7.5         Ivica Zubac            1
# 1   2.9  0.6  0.2  0.3  0.6  1.1   3.7         Ivica Zubac            2
# 2   6.1  1.1  0.2  0.9  1.2  2.3   8.9         Ivica Zubac            3
# 0   NaN  0.9  NaN  NaN  NaN  3.3   4.9          Matt Zunic            1
#
# [11363 rows x 32 columns]

# %%
youngplayers = threeseasons[(threeseasons['SEASON_COUNT'] <3) & (threeseasons['SEASON'].isin(['2020-21','2019-20','2018-19'])) ]

# %%
youngplayers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 539 entries, 0 to 1
# Data columns (total 32 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   SEASON        539 non-null    object
#  1   AGE           539 non-null    float64
#  2   TEAM          539 non-null    object
#  3   LEAGUE        539 non-null    object
#  4   POS           539 non-null    object
#  5   G             539 non-null    object
#  6   GS            539 non-null    object
#  7   MP            539 non-null    object
#  8   FG            539 non-null    object
#  9   FGA           539 non-null    object
#  10  FG%           533 non-null    object
#  11  3P            539 non-null    object
#  12  3PA           539 non-null    object
#  13  3P%           492 non-null    object
#  14  2P            539 non-null    object
#  15  2PA           539 non-null    object
#  16  2P%           524 non-null    object
#  17  eFG%          533 non-null    object
#  18  FT            539 non-null    object
#  19  FTA           539 non-null    object
#  20  FT%           487 non-null    object
#  21  ORB           539 non-null    object
#  22  DRB           539 non-null    object
#  23  TRB           539 non-null    object
#  24  AST           539 non-null    object
#  25  STL           539 non-null    object
#  26  BLK           539 non-null    object
#  27  TOV           539 non-null    object
#  28  PF            539 non-null    object
#  29  PTS           539 non-null    object
#  30  PLAYER        539 non-null    object
#  31  SEASON_COUNT  539 non-null    int64
# dtypes: float64(1), int64(1), object(30)
# memory usage: 139.0+ KB

# %%
#using concat to drop young players under 3 years who dont have chance to make All-NBA Teams yet and 
#therefore will not be in our train/test splits. Can run predicitive model on them later to see what it shows.

# %%
final=pd.concat([threeseasons, youngplayers, youngplayers]).drop_duplicates(keep=False)

# %%
finalexp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10824 entries, 2 to 0
# Data columns (total 32 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   SEASON        10824 non-null  object
#  1   AGE           10801 non-null  float64
#  2   TEAM          10824 non-null  object
#  3   LEAGUE        10824 non-null  object
#  4   POS           9927 non-null   object
#  5   G             10817 non-null  object
#  6   GS            6749 non-null   object
#  7   MP            9984 non-null   object
#  8   FG            10816 non-null  object
#  9   FGA           10815 non-null  object
#  10  FG%           10747 non-null  object
#  11  3P            7732 non-null   object
#  12  3PA           7732 non-null   object
#  13  3P%           6254 non-null   object
#  14  2P            8471 non-null   object
#  15  2PA           8471 non-null   object
#  16  2P%           8392 non-null   object
#  17  eFG%          8412 non-null   object
#  18  FT            10816 non-null  object
#  19  FTA           10816 non-null  object
#  20  FT%           10320 non-null  object
#  21  ORB           8282 non-null   object
#  22  DRB           8271 non-null   object
#  23  TRB           10085 non-null  object
#  24  AST           10815 non-null  object
#  25  STL           7744 non-null   object
#  26  BLK           7751 non-null   object
#  27  TOV           8001 non-null   object
#  28  PF            10816 non-null  object
#  29  PTS           10816 non-null  object
#  30  PLAYER        10824 non-null  object
#  31  SEASON_COUNT  10824 non-null  int64
# dtypes: float64(1), int64(1), object(30)
# memory usage: 2.7+ MB
