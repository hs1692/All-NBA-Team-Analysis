# %%
import pandas as pd
import pickle
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
df=pd.read_pickle('data/cleaned_data')

# %%
df
# Out:
#        SEASON   AGE TEAM LEAGUE POS     G    GS    MP   FG   FGA  ...  DRB  \
# 0     2020-21  19.0  ORL    NBA  SG  26.0   1.0  25.2  4.3   9.7  ...  4.2
# 1     2020-21  22.0  PHI    NBA  SG   6.0   0.0   4.5  0.8   1.5  ...  0.2
# 2     2020-21  24.0  CLE    NBA  SG  28.0   1.0  13.4  1.3   3.6  ...  1.5
# 3     1992-93  24.0  TOT    NBA  PF  75.0  52.0  17.5  3.3   6.3  ...  2.8
# 4     1968-69  22.0  MIL    NBA   C  29.0   NaN  28.9  4.3  12.0  ...  NaN
# ...       ...   ...  ...    ...  ..   ...   ...   ...  ...   ...  ...  ...
# 3076  2014-15  25.0  BOS    NBA   C  82.0  59.0  21.1  4.1   7.5  ...  3.9
# 3077  2002-03  25.0  LAC    NBA   C  41.0   1.0  10.0  1.5   4.0  ...  1.2
# 3078  1996-97  23.0  CHH    NBA   C  36.0   2.0   8.0  0.9   2.4  ...  1.1
# 3079  2019-20  23.0  CLE    NBA   C  22.0   0.0  10.0  1.9   3.3  ...  2.2
# 3080  2018-19  21.0  TOT    NBA   C  59.0  37.0  17.6  3.6   6.4  ...  4.2
#
#        TRB  AST  STL  BLK  TOV   PF   PTS  SEASON_COUNT  target
# ...
